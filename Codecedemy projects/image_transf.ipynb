# %%
import numpy as np
import matplotlib.pyplot as plt

heart_img = np.array([[255,0,0,255,0,0,255],
              [0,255/2,255/2,0,255/2,255/2,0],
          [0,255/2,255/2,255/2,255/2,255/2,0],
          [0,255/2,255/2,255/2,255/2,255/2,0],
              [255,0,255/2,255/2,255/2,0,255],
                  [255,255,0,255/2,0,255,255],
                  [255,255,255,0,255,255,255]])

# This is a helper function that makes it easy for you to show images!
def show_image(image, name_identifier):
    # render image function
  plt.imshow(image, cmap="inferno_r")
  plt.title(name_identifier)
  plt.show()

show_image(heart_img,"heart")
# Invert color


# Rotate heart


# Random Image


# Solve for heart image

# %%
vector1 = [3,-1,2]
vector2 = [0,-1,1]
vector = [-2,-3,0,5,1]

prod  = np.matmul(vector1,vector2)
prod
length1 = np.linalg.norm(vector1) 
length2 = np.linalg.norm(vector2)
phi = np.arccos(prod/(length1*length2))
np.degrees(phi)
length3 = np.linalg.norm(vector)
length3
# Out:
# 6.244997998398398

# %%
heart_img.shape
heart_img[6,6]
heart_img[3,3]
heart_img[1,3]

inverted_heart_img = (heart_img- np.arange(255,255+49/2, 0.5, dtype=int).reshape(7,7) )*-1
rotated_heart_img = heart_img.T
name = "Rotated Heart Image"
show_image(rotated_heart_img,name)
random_img = np.random.randint(0,255,(7,7))

# %%
heart_img
# Out:
# array([[255. ,   0. ,   0. , 255. ,   0. ,   0. , 255. ],
#        [  0. , 127.5, 127.5,   0. , 127.5, 127.5,   0. ],
#        [  0. , 127.5, 127.5, 127.5, 127.5, 127.5,   0. ],
#        [  0. , 127.5, 127.5, 127.5, 127.5, 127.5,   0. ],
#        [255. ,   0. , 127.5, 127.5, 127.5,   0. , 255. ],
#        [255. , 255. ,   0. , 127.5,   0. , 255. , 255. ],
#        [255. , 255. , 255. ,   0. , 255. , 255. , 255. ]])

# %%
show_image(random_img,name)
result = np.linalg.solve(random_img,heart_img)

# %%
prod = np.matmul(random_img,result)

# %%
arr = np.identity(7)
permut = np.random.permutation(arr)
new_perm = heart_img@permut

# %%
show_image(new_perm,name)

# %%
permutation_matrix =

# %%
np.arange(255,255+49/2, 0.5, dtype=int).reshape(7,7)
# Out:
# array([[255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255]])
